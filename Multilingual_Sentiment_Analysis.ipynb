# %% [markdown]
# <a href="https://colab.research.google.com/github/Trickster0708/Transformer/blob/main/Multilingual_Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers torch -q

# %%
from transformers import pipeline
classifier = pipeline(
    "sentiment-analysis",
    model="tabularisai/multilingual-sentiment-analysis"
)
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/851 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  541MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.92M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]

# %%
reviews = [
    "The product is excellent!",                # English
    "यह उत्पाद बहुत अच्छा है।",                 # Hindi
    "El producto es excelente."                # Spanish
]

# %%
results = classifier(reviews)

for review, result in zip(reviews, results):
    print(f"Review: {review}")
    print(f"Prediction: {result}")
    print()
# Out:
# Review: The product is excellent!
# Prediction: {'label': 'Positive', 'score': 0.6938655376434326}
#
# Review: यह उत्पाद बहुत अच्छा है।
# Prediction: {'label': 'Positive', 'score': 0.8585635423660278}
#
# Review: El producto es excelente.
# Prediction: {'label': 'Positive', 'score': 0.8151363134384155}
